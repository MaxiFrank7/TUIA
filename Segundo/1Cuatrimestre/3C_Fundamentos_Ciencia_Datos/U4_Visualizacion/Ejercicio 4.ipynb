# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### **Ejercicio N°4**
# Utilizando el dataset `iris.csv` del **Ejercicio N°1**:

# %%
iris=pd.read_csv('./datasets/iris.csv')
iris
# Out:
#       id  sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0      1              5.1             3.5              1.4             0.2
# 1      2              4.9             3.0              1.4             0.2
# 2      3              4.7             3.2              1.3             0.2
# 3      4              4.6             3.1              1.5             0.2
# 4      5              5.0             3.6              1.4             0.2
# ..   ...              ...             ...              ...             ...
# 145  146              6.7             3.0              5.2             2.3
# 146  147              6.3             2.5              5.0             1.9
# 147  148              6.5             3.0              5.2             2.0
# 148  149              6.2             3.4              5.4             2.3
# 149  150              5.9             3.0              5.1             1.8
#
#             species
# 0       Iris-setosa
# 1       Iris-setosa
# ...

# %% [markdown]
# 1. Construya un gráfico que le permita visualizar la distribución de los valores observados del ancho de sépalo. A partir del gráfico realizado, ¿qué puede decir acerca de la simetría de la distribución?

# %%
sns.histplot(data=iris, x='sepal_width_cm', kde=True, color='darkred', edgecolor='black')
plt.title('Distribución del Ancho de Sépalo', fontweight='bold')
plt.xlabel('Ancho de sépalo (cm)', fontweight='bold')
plt.ylabel('Frecuencia', fontweight='bold')
plt.show()

# %% [markdown]
# 2. Realice un gráfico que permita comparar la distribución del largo del pétalo de las flores entre las distintas especies. Comente brevemente lo observado.

# %%
#sns.boxplot(data=iris, x='species', y='petal_length_cm', palette='Set2')
sns.kdeplot(data=iris,x='petal_length_cm',hue='species',fill=True)
plt.title('Distribución del Largo del Pétalo por Especie', fontweight='bold')
plt.xlabel('Especie', fontweight='bold')
plt.ylabel('Largo de pétalo (cm)', fontweight='bold')
plt.show()

# %% [markdown]
# 3. Construya un gráfico que le permita analizar la relación general que existe entre las variables ancho y largo del pétalo. ¿Qué observa?

# %%
sns.scatterplot(data=iris,x='petal_length_cm',y='petal_width_cm')
plt.title('Relación entre Ancho y Largo del Pétalo (General)', fontweight='bold')
plt.xlabel('Ancho del pétalo (cm)', fontweight='bold')
plt.ylabel('Largo del pétalo (cm)', fontweight='bold')
plt.show()

# %% [markdown]
# 4. Modifique el gráfico realizado en el ítem anterior de tal manera que le permita analizar si la relación general entre el ancho y el largo del pétalo se mantiene según la especie. Comente brevemente lo observado.

# %%
sns.scatterplot(data=iris,x='petal_length_cm',y='petal_width_cm',hue='species')
plt.title('Relación entre Ancho y Largo del Pétalo por Especie', fontweight='bold')
plt.xlabel('Ancho del pétalo (cm)', fontweight='bold')
plt.ylabel('Largo del pétalo (cm)', fontweight='bold')
plt.legend(title='Especie')
plt.show()

# %% [markdown]
# 5. Construya una matriz de gráficos que le permitan estudiar la asociación que existe entre todos los pares de variables cuantitativas del dataset. *Sugerencia*: utilice la función **`pairplot()`** de **Seaborn**.

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               150 non-null    int64
#  1   sepal_length_cm  150 non-null    float64
#  2   sepal_width_cm   150 non-null    float64
#  3   petal_length_cm  150 non-null    float64
#  4   petal_width_cm   150 non-null    float64
#  5   species          150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
cuantitativas=['sepal_length_cm','sepal_width_cm','petal_length_cm','petal_width_cm','species']

# %%
sns.pairplot(iris[cuantitativas], hue='species')
plt.suptitle('Matriz de relaciones entre variables cuantitativas', y=1.02, fontweight='bold')
plt.show()

# %% [markdown]
# 6. Sobre las mismas variables cuantitativas del dataset, genere la matriz de correlación lineal de Pearson y represéntela gráficamente a través de un correlograma.

# %%
cuantitativas=['sepal_length_cm','sepal_width_cm','petal_length_cm','petal_width_cm']
matriz_correlacion=iris[cuantitativas].corr(method='pearson')

plt.figure(figsize=(7, 6))
sns.heatmap(matriz_correlacion, annot=True, vmin=-1, vmax=1, fmt=".2f", linewidths=0.5,cmap='coolwarm')
plt.title('Correlograma: Correlación Lineal de Pearson', fontweight='bold')
plt.show()

# %% [markdown]
# 7. A partir de lo realizado en los dos ítems anteriores, caracterice el grado de asociación lineal entre los distintos pares de variables de interés, incluyendo fuerza y dirección, y analizando la correspondencia entre los valores calculados y lo observado gráficamente.
#
#     * Petalo ancho vs largo tienen asociacion lineal muy fuerte y positiva(r=0.96)
#     * Petalo largo vs sepalo largo tienen asociacion lineal muy fuerte y positiva(r=0.87)
#     * Petalo ancho vs sepalo largo tienen asociacion lineal fuerte y positiva(r=0.82)
#     * Sepalo ancho y sepalo largo tienen asociacion lineal casi nula r=-0.11
